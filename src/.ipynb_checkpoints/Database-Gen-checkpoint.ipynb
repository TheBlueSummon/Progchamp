# %%
start = 0
end = 10
count = 100
pages = 2

# %%
import yaml
import requests

# URL of the languages.yml file in the GitHub Linguist repository
url = "https://raw.githubusercontent.com/github/linguist/b3664e4f242c842e356bd011090f85514d147948/lib/linguist/languages.yml"

# Fetch the content of the YAML file
response = requests.get(url)
yaml_content = response.text

# Parse the YAML content
languages_data = yaml.safe_load(yaml_content)

# Extract language names
languages = list(languages_data.keys())

# %%
import requests
import json

# GitHub API base URL
base_url = "https://api.github.com"

# GitHub personal access token
# Replace 'YOUR_ACCESS_TOKEN' with your actual token
access_token = 'YOUR_ACCESS_TOKEN'

# Function to fetch repository metadata for a given language
def fetch_repo_metadata(language, page):
    # Endpoint to search repositories by language
    search_endpoint = f"{base_url}/search/repositories"
    
    # Query parameters for the search endpoint
    params = {
        'q': f'language:{language}',
        'sort': 'stars',
        'order': 'desc',
        'per_page': 100,  # Number of results per page (maximum allowed)
        'page': page
    }
    
    # Headers including the access token
    headers = {
        'Authorization': f'token {access_token}',
        'Accept': 'application/vnd.github.v3+json'
    }

    # Make the API request
    response = requests.get(search_endpoint, params=params, headers=headers)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        
        # Extract the first few repositories
        repositories = data['items'][:count]
        
        # Fetch language data for each repository and extract only required metadata
        repo_metadata = []
        for repo in repositories:
            # Fetch language data for the repository
            language_url = f"{base_url}/repos/{repo['full_name']}/languages"
            language_response = requests.get(language_url, headers=headers)
            if language_response.status_code == 200:
                # Parse language data
                languages = language_response.json()
                
                # Extract required metadata
                metadata = {
                    'name': repo['name'],
                    'description': repo['description'],
                    'languages': languages
                }
                
                repo_metadata.append(metadata)
            else:
                print(f"Failed to fetch language data for {repo['full_name']}. Status code: {language_response.status_code}")
        
        # Return metadata for each repository
        return repo_metadata
    else:
        # Print error message if request failed
        print(f"Failed to fetch repositories for {language}. Status code: {response.status_code}")
        return None

# Function to store repository metadata in a JSON file
def store_metadata(language, metadata):
    # File path to store metadata
    file_path = f"{language}_repos_metadata.json"
    
    # Write metadata to the JSON file
    with open(file_path, 'w') as file:
        json.dump(metadata, file, indent=4)
    
    print(f"Metadata for {language} repositories stored successfully in {file_path}")

# Iterate over each language
for i in range(start,end):
    language = languages[i]
    print(f"Fetching metadata for {language} repositories...")
        
    # Fetch repository metadata
    all_metadata = []
    for p in range(1,pages+1):
        repo_metadata = fetch_repo_metadata(language,p)
        if repo_metadata:
            all_metadata.extend(repo_metadata)
        
    # Store metadata in a JSON file
    if repo_metadata:
        store_metadata(language, all_metadata)
        
    print(f"Metadata retrieval for {language} complete.\n")
# Out:
# Fetching metadata for 1C Enterprise repositories...
# Metadata for 1C Enterprise repositories stored successfully in 1C Enterprise_repos_metadata.json
# Metadata retrieval for 1C Enterprise complete.
#
# Fetching metadata for 4D repositories...
# Metadata for 4D repositories stored successfully in 4D_repos_metadata.json
# Metadata retrieval for 4D complete.
#
# Fetching metadata for ABAP repositories...
# Metadata for ABAP repositories stored successfully in ABAP_repos_metadata.json
# Metadata retrieval for ABAP complete.
#
# Fetching metadata for ABNF repositories...
# Metadata for ABNF repositories stored successfully in ABNF_repos_metadata.json
# Metadata retrieval for ABNF complete.
#
# Fetching metadata for AGS Script repositories...
# Metadata for AGS Script repositories stored successfully in AGS Script_repos_metadata.json
# Metadata retrieval for AGS Script complete.
#
# Fetching metadata for AL repositories...
# Metadata for AL repositories stored successfully in AL_repos_metadata.json
# Metadata retrieval for AL complete.
#
# Fetching metadata for AMPL repositories...
# Metadata for AMPL repositories stored successfully in AMPL_repos_metadata.json
# Metadata retrieval for AMPL complete.
#
# Fetching metadata for ANTLR repositories...
# Metadata for ANTLR repositories stored successfully in ANTLR_repos_metadata.json
# Metadata retrieval for ANTLR complete.
#
# Fetching metadata for API Blueprint repositories...
# Metadata for API Blueprint repositories stored successfully in API Blueprint_repos_metadata.json
# Metadata retrieval for API Blueprint complete.
#
# Fetching metadata for APL repositories...
# Metadata for APL repositories stored successfully in APL_repos_metadata.json
# Metadata retrieval for APL complete.
#
# Fetching metadata for ASL repositories...
# Metadata for ASL repositories stored successfully in ASL_repos_metadata.json
# Metadata retrieval for ASL complete.
#
# Fetching metadata for ASN.1 repositories...
# Metadata for ASN.1 repositories stored successfully in ASN.1_repos_metadata.json
# Metadata retrieval for ASN.1 complete.
#
# Fetching metadata for ASP.NET repositories...
# Metadata for ASP.NET repositories stored successfully in ASP.NET_repos_metadata.json
# Metadata retrieval for ASP.NET complete.
#
# Fetching metadata for ATS repositories...
# Metadata for ATS repositories stored successfully in ATS_repos_metadata.json
# Metadata retrieval for ATS complete.
#
# Fetching metadata for ActionScript repositories...
# Metadata for ActionScript repositories stored successfully in ActionScript_repos_metadata.json
# Metadata retrieval for ActionScript complete.
#
# Fetching metadata for Ada repositories...
# Metadata for Ada repositories stored successfully in Ada_repos_metadata.json
# Metadata retrieval for Ada complete.
#
# Fetching metadata for Adobe Font Metrics repositories...
# Metadata for Adobe Font Metrics repositories stored successfully in Adobe Font Metrics_repos_metadata.json
# Metadata retrieval for Adobe Font Metrics complete.
#
# Fetching metadata for Agda repositories...
# Metadata for Agda repositories stored successfully in Agda_repos_metadata.json
# Metadata retrieval for Agda complete.
#
# Fetching metadata for Alloy repositories...
# Metadata for Alloy repositories stored successfully in Alloy_repos_metadata.json
# Metadata retrieval for Alloy complete.
#
# Fetching metadata for Alpine Abuild repositories...
# Metadata for Alpine Abuild repositories stored successfully in Alpine Abuild_repos_metadata.json
# Metadata retrieval for Alpine Abuild complete.
#
# Fetching metadata for Altium Designer repositories...
# Metadata for Altium Designer repositories stored successfully in Altium Designer_repos_metadata.json
# Metadata retrieval for Altium Designer complete.
#
# Fetching metadata for AngelScript repositories...
# Metadata for AngelScript repositories stored successfully in AngelScript_repos_metadata.json
# Metadata retrieval for AngelScript complete.
#
# Fetching metadata for Ant Build System repositories...
# Metadata for Ant Build System repositories stored successfully in Ant Build System_repos_metadata.json
# Metadata retrieval for Ant Build System complete.
#
# Fetching metadata for ApacheConf repositories...
# Metadata for ApacheConf repositories stored successfully in ApacheConf_repos_metadata.json
# Metadata retrieval for ApacheConf complete.
#
# Fetching metadata for Apex repositories...
# Metadata for Apex repositories stored successfully in Apex_repos_metadata.json
# Metadata retrieval for Apex complete.
#
# Fetching metadata for Apollo Guidance Computer repositories...
# Metadata for Apollo Guidance Computer repositories stored successfully in Apollo Guidance Computer_repos_metadata.json
# Metadata retrieval for Apollo Guidance Computer complete.
#
# Fetching metadata for AppleScript repositories...
# Metadata for AppleScript repositories stored successfully in AppleScript_repos_metadata.json
# Metadata retrieval for AppleScript complete.
#
# Fetching metadata for Arc repositories...
# Metadata for Arc repositories stored successfully in Arc_repos_metadata.json
# Metadata retrieval for Arc complete.
#
# Fetching metadata for AsciiDoc repositories...
# Metadata for AsciiDoc repositories stored successfully in AsciiDoc_repos_metadata.json
# Metadata retrieval for AsciiDoc complete.
#
# Fetching metadata for AspectJ repositories...
# Metadata for AspectJ repositories stored successfully in AspectJ_repos_metadata.json
# Metadata retrieval for AspectJ complete.
#
# Fetching metadata for Assembly repositories...
# Metadata for Assembly repositories stored successfully in Assembly_repos_metadata.json
# Metadata retrieval for Assembly complete.
#
# Fetching metadata for Asymptote repositories...
# Metadata for Asymptote repositories stored successfully in Asymptote_repos_metadata.json
# Metadata retrieval for Asymptote complete.
#
# Fetching metadata for Augeas repositories...
# Metadata for Augeas repositories stored successfully in Augeas_repos_metadata.json
# Metadata retrieval for Augeas complete.
#
# Fetching metadata for AutoHotkey repositories...
# Metadata for AutoHotkey repositories stored successfully in AutoHotkey_repos_metadata.json
# Metadata retrieval for AutoHotkey complete.
#
# Fetching metadata for AutoIt repositories...
# Metadata for AutoIt repositories stored successfully in AutoIt_repos_metadata.json
# Metadata retrieval for AutoIt complete.
#
# Fetching metadata for Avro IDL repositories...
# Metadata for Avro IDL repositories stored successfully in Avro IDL_repos_metadata.json
# Metadata retrieval for Avro IDL complete.
#
# Fetching metadata for Awk repositories...
# Metadata for Awk repositories stored successfully in Awk_repos_metadata.json
# Metadata retrieval for Awk complete.
#
# Fetching metadata for Ballerina repositories...
# Metadata for Ballerina repositories stored successfully in Ballerina_repos_metadata.json
# Metadata retrieval for Ballerina complete.
#
# Fetching metadata for Batchfile repositories...
# Metadata for Batchfile repositories stored successfully in Batchfile_repos_metadata.json
# Metadata retrieval for Batchfile complete.
#
# Fetching metadata for Befunge repositories...
# Metadata for Befunge repositories stored successfully in Befunge_repos_metadata.json
# Metadata retrieval for Befunge complete.
#
# Fetching metadata for BibTeX repositories...
# Metadata retrieval for BibTeX complete.
#
# Fetching metadata for Bison repositories...
# Metadata for Bison repositories stored successfully in Bison_repos_metadata.json
# Metadata retrieval for Bison complete.
#
# Fetching metadata for BitBake repositories...
# Metadata for BitBake repositories stored successfully in BitBake_repos_metadata.json
# Metadata retrieval for BitBake complete.
#
# Fetching metadata for Blade repositories...
# Metadata for Blade repositories stored successfully in Blade_repos_metadata.json
# Metadata retrieval for Blade complete.
#
# Fetching metadata for BlitzBasic repositories...
# Metadata for BlitzBasic repositories stored successfully in BlitzBasic_repos_metadata.json
# Metadata retrieval for BlitzBasic complete.
#
# Fetching metadata for BlitzMax repositories...
# Metadata for BlitzMax repositories stored successfully in BlitzMax_repos_metadata.json
# Metadata retrieval for BlitzMax complete.
#
# Fetching metadata for Bluespec repositories...
# Metadata for Bluespec repositories stored successfully in Bluespec_repos_metadata.json
# Metadata retrieval for Bluespec complete.
#
# Fetching metadata for Boo repositories...
# Metadata for Boo repositories stored successfully in Boo_repos_metadata.json
# Metadata retrieval for Boo complete.
#
# Fetching metadata for Brainfuck repositories...
# Metadata for Brainfuck repositories stored successfully in Brainfuck_repos_metadata.json
# Metadata retrieval for Brainfuck complete.
#
# Fetching metadata for Brightscript repositories...
# Metadata for Brightscript repositories stored successfully in Brightscript_repos_metadata.json
# Metadata retrieval for Brightscript complete.
#
# Fetching metadata for C repositories...
# Metadata for C repositories stored successfully in C_repos_metadata.json
# Metadata retrieval for C complete.
#
# Fetching metadata for C# repositories...
# Metadata for C# repositories stored successfully in C#_repos_metadata.json
# Metadata retrieval for C# complete.
#
# Fetching metadata for C++ repositories...
# Metadata for C++ repositories stored successfully in C++_repos_metadata.json
# Metadata retrieval for C++ complete.
#
# Fetching metadata for C-ObjDump repositories...
# Metadata retrieval for C-ObjDump complete.
#
# Fetching metadata for C2hs Haskell repositories...
# Metadata retrieval for C2hs Haskell complete.
#
# Fetching metadata for CLIPS repositories...
# Metadata for CLIPS repositories stored successfully in CLIPS_repos_metadata.json
# Metadata retrieval for CLIPS complete.
#
# Fetching metadata for CMake repositories...
# Metadata for CMake repositories stored successfully in CMake_repos_metadata.json
# Metadata retrieval for CMake complete.
#
# Fetching metadata for COBOL repositories...
# Metadata for COBOL repositories stored successfully in COBOL_repos_metadata.json
# Metadata retrieval for COBOL complete.
#
# Fetching metadata for COLLADA repositories...
# Metadata retrieval for COLLADA complete.
#
# Fetching metadata for CSON repositories...
# Metadata for CSON repositories stored successfully in CSON_repos_metadata.json
# Metadata retrieval for CSON complete.
#
# Fetching metadata for CSS repositories...
# Metadata for CSS repositories stored successfully in CSS_repos_metadata.json
# Metadata retrieval for CSS complete.
#
# Fetching metadata for CSV repositories...
# Metadata for CSV repositories stored successfully in CSV_repos_metadata.json
# Metadata retrieval for CSV complete.
#
# Fetching metadata for CWeb repositories...
# Metadata for CWeb repositories stored successfully in CWeb_repos_metadata.json
# Metadata retrieval for CWeb complete.
#
# Fetching metadata for Cabal Config repositories...
# Metadata retrieval for Cabal Config complete.
#
# Fetching metadata for Cap'n Proto repositories...
# Metadata for Cap'n Proto repositories stored successfully in Cap'n Proto_repos_metadata.json
# Metadata retrieval for Cap'n Proto complete.
#
# Fetching metadata for CartoCSS repositories...
# Metadata for CartoCSS repositories stored successfully in CartoCSS_repos_metadata.json
# Metadata retrieval for CartoCSS complete.
#
# Fetching metadata for Ceylon repositories...
# Metadata for Ceylon repositories stored successfully in Ceylon_repos_metadata.json
# Metadata retrieval for Ceylon complete.
#
# Fetching metadata for Chapel repositories...
# Metadata for Chapel repositories stored successfully in Chapel_repos_metadata.json
# Metadata retrieval for Chapel complete.
#
# Fetching metadata for Charity repositories...
# Metadata for Charity repositories stored successfully in Charity_repos_metadata.json
# Metadata retrieval for Charity complete.
#
# Fetching metadata for ChucK repositories...
# Metadata for ChucK repositories stored successfully in ChucK_repos_metadata.json
# Metadata retrieval for ChucK complete.
#
# Fetching metadata for Cirru repositories...
# Metadata for Cirru repositories stored successfully in Cirru_repos_metadata.json
# Metadata retrieval for Cirru complete.
#
# Fetching metadata for Clarion repositories...
# Metadata for Clarion repositories stored successfully in Clarion_repos_metadata.json
# Metadata retrieval for Clarion complete.
#
# Fetching metadata for Classic ASP repositories...
# Metadata for Classic ASP repositories stored successfully in Classic ASP_repos_metadata.json
# Metadata retrieval for Classic ASP complete.
#
# Fetching metadata for Clean repositories...
# Metadata for Clean repositories stored successfully in Clean_repos_metadata.json
# Metadata retrieval for Clean complete.
#
# Fetching metadata for Click repositories...
# Metadata for Click repositories stored successfully in Click_repos_metadata.json
# Metadata retrieval for Click complete.
#
# Fetching metadata for Clojure repositories...
# Metadata for Clojure repositories stored successfully in Clojure_repos_metadata.json
# Metadata retrieval for Clojure complete.
#
# Fetching metadata for Closure Templates repositories...
# Metadata for Closure Templates repositories stored successfully in Closure Templates_repos_metadata.json
# Metadata retrieval for Closure Templates complete.
#
# Fetching metadata for Cloud Firestore Security Rules repositories...
# Metadata for Cloud Firestore Security Rules repositories stored successfully in Cloud Firestore Security Rules_repos_metadata.json
# Metadata retrieval for Cloud Firestore Security Rules complete.
#
# Fetching metadata for CoNLL-U repositories...
# Metadata retrieval for CoNLL-U complete.
#
# Fetching metadata for CodeQL repositories...
# Metadata for CodeQL repositories stored successfully in CodeQL_repos_metadata.json
# Metadata retrieval for CodeQL complete.
#
# Fetching metadata for CoffeeScript repositories...
# Metadata for CoffeeScript repositories stored successfully in CoffeeScript_repos_metadata.json
# Metadata retrieval for CoffeeScript complete.
#
# Fetching metadata for ColdFusion repositories...
# Metadata for ColdFusion repositories stored successfully in ColdFusion_repos_metadata.json
# Metadata retrieval for ColdFusion complete.
#
# Fetching metadata for ColdFusion CFC repositories...
